# %%
# %pip install -U ddgs
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\Sanjog Bhalla\Desktop\Langgraph - CampusX\myenv\Scripts\python.exe: No module named pip

# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict, Annotated, Literal 
from langchain_core.messages import BaseMessage, HumanMessage
from langchain_openai import ChatOpenAI
from langgraph.graph.message import add_messages
from dotenv import load_dotenv

from langgraph.prebuilt import ToolNode, tools_condition
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_core.tools import tool

import requests
import random

# %%
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\Sanjog Bhalla\Desktop\Langgraph - CampusX\myenv\Scripts\python.exe: No module named pip

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatOpenAI()
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in .\myenv\Lib\site-packages (from langchain-community) (1.3.0)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community)
#   Downloading langchain_classic-1.0.4-py3-none-any.whl.metadata (4.8 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain-community)
#   Downloading sqlalchemy-2.0.49-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in .\myenv\Lib\site-packages (from langchain-community) (2.33.1)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in .\myenv\Lib\site-packages (from langchain-community) (6.0.3)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.13.5-cp313-cp313-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in .\myenv\Lib\site-packages (from langchain-community) (9.1.4)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.14.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in .\myenv\Lib\site-packages (from langchain-community) (0.7.32)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting numpy>=2.1.0 (from langchain-community)
#   Using cached numpy-2.4.4-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading frozenlist-1.8.0-cp313-cp313-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading multidict-6.7.1-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading propcache-0.4.1-cp313-cp313-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading yarl-1.23.0-cp313-cp313-win_amd64.whl.metadata (82 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in .\myenv\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.13.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in .\myenv\Lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in .\myenv\Lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (26.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in .\myenv\Lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in .\myenv\Lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in .\myenv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in .\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in .\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in .\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in .\myenv\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: anyio in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.13.0)
# Requirement already satisfied: certifi in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.11)
# Requirement already satisfied: h11>=0.16 in .\myenv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\myenv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.2 in .\myenv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.46.2)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\myenv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in .\myenv\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\myenv\Lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in .\myenv\Lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.3)
# Collecting greenlet>=1 (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community)
#   Using cached greenlet-3.5.0-cp313-cp313-win_amd64.whl.metadata (3.8 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ------------ --------------------------- 0.8/2.5 MB 2.4 MB/s eta 0:00:01
#    ------------ --------------------------- 0.8/2.5 MB 2.4 MB/s eta 0:00:01
#    -------------------- ------------------- 1.3/2.5 MB 1.8 MB/s eta 0:00:01
#    -------------------- ------------------- 1.3/2.5 MB 1.8 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.8/2.5 MB 1.2 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 1.4 MB/s  0:00:01
# Downloading aiohttp-3.13.5-cp313-cp313-win_amd64.whl (458 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.4-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 1.1 MB/s eta 0:00:01
#    -------------------- ------------------- 0.5/1.0 MB 1.1 MB/s eta 0:00:01
#    -------------------- ------------------- 0.5/1.0 MB 1.1 MB/s eta 0:00:01
#    ------------------------------ --------- 0.8/1.0 MB 586.3 kB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 746.2 kB/s  0:00:01
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Downloading multidict-6.7.1-cp313-cp313-win_amd64.whl (45 kB)
# Downloading pydantic_settings-2.14.0-py3-none-any.whl (60 kB)
# Downloading sqlalchemy-2.0.49-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ------------------- -------------------- 1.0/2.1 MB 3.0 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 2.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 2.2 MB/s  0:00:00
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.23.0-cp313-cp313-win_amd64.whl (87 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-26.1.0-py3-none-any.whl (67 kB)
# Downloading frozenlist-1.8.0-cp313-cp313-win_amd64.whl (43 kB)
# Using cached greenlet-3.5.0-cp313-cp313-win_amd64.whl (238 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached numpy-2.4.4-cp313-cp313-win_amd64.whl (12.3 MB)
# Downloading propcache-0.4.1-cp313-cp313-win_amd64.whl (40 kB)
# Installing collected packages: propcache, numpy, mypy-extensions, multidict, marshmallow, httpx-sse, greenlet, frozenlist, attrs, aiohappyeyeballs, yarl, typing-inspect, SQLAlchemy, aiosignal, pydantic-settings, dataclasses-json, aiohttp, langchain-text-splitters, langchain-classic, langchain-community
#
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    -- -------------------------------------  1/20 [numpy]
#    ------ ---------------------------------  3/20 [multidict]
#    ------ ---------------------------------  3/20 [multidict]
#    -------- -------------------------------  4/20 [marshmallow]
#    -------- -------------------------------  4/20 [marshmallow]
#    -------- -------------------------------  4/20 [marshmallow]
#    -------- -------------------------------  4/20 [marshmallow]
#    -------- -------------------------------  4/20 [marshmallow]
#    -------- -------------------------------  4/20 [marshmallow]
#    -------- -------------------------------  4/20 [marshmallow]
#    ---------- -----------------------------  5/20 [httpx-sse]
#    ---------- -----------------------------  5/20 [httpx-sse]
#    ------------ ---------------------------  6/20 [greenlet]
#    ------------ ---------------------------  6/20 [greenlet]
#    ------------ ---------------------------  6/20 [greenlet]
#    ------------ ---------------------------  6/20 [greenlet]
#    ------------ ---------------------------  6/20 [greenlet]
#    ------------ ---------------------------  6/20 [greenlet]
#    ------------ ---------------------------  6/20 [greenlet]
#    ------------ ---------------------------  6/20 [greenlet]
#    ------------ ---------------------------  6/20 [greenlet]
#    -------------- -------------------------  7/20 [frozenlist]
#    ---------------- -----------------------  8/20 [attrs]
#    ---------------- -----------------------  8/20 [attrs]
#    ---------------- -----------------------  8/20 [attrs]
#    ---------------- -----------------------  8/20 [attrs]
#    ---------------- -----------------------  8/20 [attrs]
#    ---------------- -----------------------  8/20 [attrs]
#    ---------------- -----------------------  8/20 [attrs]
#    ------------------ ---------------------  9/20 [aiohappyeyeballs]
#    ------------------ ---------------------  9/20 [aiohappyeyeballs]
#    -------------------- ------------------- 10/20 [yarl]
#    -------------------- ------------------- 10/20 [yarl]
#    -------------------- ------------------- 10/20 [yarl]
#    -------------------- ------------------- 10/20 [yarl]
#    -------------------- ------------------- 10/20 [yarl]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ------------------------ --------------- 12/20 [SQLAlchemy]
#    ---------------------------- ----------- 14/20 [pydantic-settings]
#    ---------------------------- ----------- 14/20 [pydantic-settings]
#    ---------------------------- ----------- 14/20 [pydantic-settings]
#    ---------------------------- ----------- 14/20 [pydantic-settings]
#    ---------------------------- ----------- 14/20 [pydantic-settings]
#    ---------------------------- ----------- 14/20 [pydantic-settings]
#    ---------------------------- ----------- 14/20 [pydantic-settings]
#    ---------------------------- ----------- 14/20 [pydantic-settings]
#    ---------------------------- ----------- 14/20 [pydantic-settings]
#    ------------------------------ --------- 15/20 [dataclasses-json]
#    ------------------------------ --------- 15/20 [dataclasses-json]
#    ------------------------------ --------- 15/20 [dataclasses-json]
#    ------------------------------ --------- 15/20 [dataclasses-json]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    -------------------------------- ------- 16/20 [aiohttp]
#    ---------------------------------- ----- 17/20 [langchain-text-splitters]
#    ---------------------------------- ----- 17/20 [langchain-text-splitters]
#    ---------------------------------- ----- 17/20 [langchain-text-splitters]
#    ---------------------------------- ----- 17/20 [langchain-text-splitters]
#    ---------------------------------- ----- 17/20 [langchain-text-splitters]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
#    ------------------------------------ --- 18/20 [langchain-classic]
# ...
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    -------------------------------------- - 19/20 [langchain-community]
#    ---------------------------------------- 20/20 [langchain-community]
#
# Successfully installed SQLAlchemy-2.0.49 aiohappyeyeballs-2.6.1 aiohttp-3.13.5 aiosignal-1.4.0 attrs-26.1.0 dataclasses-json-0.6.7 frozenlist-1.8.0 greenlet-3.5.0 httpx-sse-0.4.3 langchain-classic-1.0.4 langchain-community-0.4.1 langchain-text-splitters-1.1.2 marshmallow-3.26.2 multidict-6.7.1 mypy-extensions-1.1.0 numpy-2.4.4 propcache-0.4.1 pydantic-settings-2.14.0 typing-inspect-0.9.0 yarl-1.23.0
# WARNING: Ignoring invalid distribution ~ip (C:\Users\Sanjog Bhalla\Desktop\Langgraph - CampusX\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\Sanjog Bhalla\Desktop\Langgraph - CampusX\myenv\Lib\site-packages)

# %%
# Tools

search_tool = DuckDuckGoSearchRun()

@tool
def calculator(first_num: float, second_num: float, operation: str) -> dict:
    
    """
    Perform a basic arithmetic operation on two numbers.
    Supported operations: add, sub, mul, div
    """
    try: 
        if operation == "add":
            result =  first_num + second_num
        elif operation == "subtract":
            result = first_num - second_num
        elif operation == "multiply":
            result = first_num * second_num
        elif operation == "divide":
            if second_num == 0:
                return {"error": "Cannot divide by zero"}
            result =  first_num / second_num
        else:
            return {"error": f"Unsupported operation '{operation}'"}
        
        return {"first number": first_num, "second number": second_num, "operation": operation, "result": result}
    except Exception as e:
        return {"error": str(e)}
    
@tool
def get_stock_price(symbol: str) -> dict:
    """
    Fetch latest stock price for a given symbol (e.g. 'AAPL', 'TSLA') 
    using Alpha Vantage with API key in the URL.
    """
    url = f"https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol={symbol}&apikey=API_KEY"
    r = requests.get(url)
    return r.json()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Sanjog Bhalla\Desktop\Langgraph - CampusX\myenv\Lib\site-packages\langchain_community\utilities\duckduckgo_search.py:49, in DuckDuckGoSearchAPIWrapper.validate_environment(cls, values)
#      48 try:
# ---> 49     from ddgs import DDGS  # noqa: F401
#      50 except ImportError:
#
# ModuleNotFoundError: No module named 'ddgs'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Tools
#       2
# ----> 3 search_tool = DuckDuckGoSearchRun()
#       4
#       5 @tool
#       6 def calculator(first_num: float, second_num: float, operation: str) -> dict:
#
# File c:\Users\Sanjog Bhalla\Desktop\Langgraph - CampusX\myenv\Lib\site-packages\langchain_core\tools\base.py:551, in BaseTool.__init__(self, **kwargs)
#     546     msg = (
#     547         "args_schema must be a subclass of pydantic BaseModel or "
#     548         f"a JSON schema dict. Got: {kwargs['args_schema']}."
#     549     )
#     550     raise TypeError(msg)
# --> 551 super().__init__(**kwargs)
#
# File c:\Users\Sanjog Bhalla\Desktop\Langgraph - CampusX\myenv\Lib\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 2 frame]
#
# File c:\Users\Sanjog Bhalla\Desktop\Langgraph - CampusX\myenv\Lib\site-packages\langchain_community\utilities\duckduckgo_search.py:51, in DuckDuckGoSearchAPIWrapper.validate_environment(cls, values)
#      49     from ddgs import DDGS  # noqa: F401
#      50 except ImportError:
# ---> 51     raise ImportError(
#      52         "Could not import ddgs python package. "
#      53         "Please install it with `pip install -U ddgs`."
#      54     )
#      55 return values
#
# ImportError: Could not import ddgs python package. Please install it with `pip install -U ddgs`.
